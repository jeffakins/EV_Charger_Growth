# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('InBoxTestData2022.xlsx')

# %%
df
# Out:
#     YYYYMMDD  Product ID  cases
# 0   20210507       11111    557
# 1   20210507       22222   2129
# 2   20210507       33333   4386
# 3   20210516       11111    440
# 4   20210518       22222   1948
# ..       ...         ...    ...
# 93  20220417       33333   2118
# 94  20220418       22222   2442
# 95  20220427       22222   1988
# 96  20220428       11111    788
# 97  20220430       33333   2007
#
# [98 rows x 3 columns]

# %%
df['YYYYMMDD'] = pd.to_datetime(df['YYYYMMDD'], format='%Y%m%d')

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'YYYYMMDD'}>,
#         <AxesSubplot:title={'center':'Product ID'}>],
#        [<AxesSubplot:title={'center':'cases'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df['Product ID'].value_counts()
# Out:
# 22222    34
# 11111    34
# 33333    30
# Name: Product ID, dtype: int64

# %%
cases_plot = df.groupby('Product ID').cases.sum()
cases_plot
# Out:
# Product ID
# 11111    17199
# 22222    54760
# 33333    81633
# Name: cases, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=df, x='YYYYMMDD', y='cases', hue='Product ID')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   YYYYMMDD    98 non-null     int64
#  1   Product ID  98 non-null     int64
#  2   cases       98 non-null     int64
# dtypes: int64(3)
# memory usage: 2.4 KB

# %%
df[Product ID']

# %%
resample('1W').sum()
